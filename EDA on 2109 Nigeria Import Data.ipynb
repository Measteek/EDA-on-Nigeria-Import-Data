# %% [markdown]
# # Exploratory Data Analaysis on Nigeria 2019 Import data

# %%
#import the libaries to work with
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#loading the data

data = pd.read_csv('Copy of 2019 NIGERIAN IMPORT DATA.csv',encoding='unicode-escape')

# %% [markdown]
# # Undestandig the Data

# %%
data.head()
# Out:
#        S/N SCANNING_COY PREFIX  BANK_CODE                       BNK_NAM  \
# 0   9577.0          NCS     BA      214.0  First City Monument Bank PLC
# 1   6756.0          NCS     BA       44.0               Access Bank PLC
# 2  17380.0          NCS     BA       23.0      Citibank Nigeria Limited
# 3  18398.0          NCS     BA       23.0      Citibank Nigeria Limited
# 4   4799.0          NCS     BA       23.0      Citibank Nigeria Limited
#
#    BANK_NUMBERING          MFNUM  APP_YEAR AUTHORIZED_DEALER_DATE  EXC_RATE  \
# 0    2.019000e+10  MF20190010578    2019.0              31-Jan-19     0.534
# 1    2.019000e+10  MF20190006942    2019.0              23-Jan-19   311.738
# 2    2.019000e+10  MF20190018966    2019.0              27-Feb-19   308.819
# 3    2.019000e+10  MF20190020044    2019.0               1-Mar-19   308.819
# 4    2.019000e+10  MF20190036985    2019.0              12-Apr-19   308.214
#
#    ...               APPLICANT_NAME  \
# ...

# %%
data.tail()
# Out:
#            S/N SCANNING_COY PREFIX  BANK_CODE          BNK_NAM  \
# 62235  20781.0          NCS     BA       57.0  Zenith Bank PLC
# 62236  31796.0          NCS     BA       57.0  Zenith Bank PLC
# 62237  37455.0          NCS     BA       57.0  Zenith Bank PLC
# 62238      NaN          NaN    NaN        NaN              NaN
# 62239      NaN          NaN    NaN        NaN              NaN
#
#        BANK_NUMBERING          MFNUM  APP_YEAR AUTHORIZED_DEALER_DATE  \
# 62235    2.019001e+10  MF20190039473    2019.0               3-Jun-19
# 62236    2.019001e+10  MF20190068367    2019.0               5-Jul-19
# 62237    2.019001e+10  MF20190074229    2019.0              22-Jul-19
# 62238             NaN            NaN       NaN                    NaN
# 62239             NaN            NaN       NaN                    NaN
#
#        EXC_RATE  ...              APPLICANT_NAME  \
# 62235   21.6970  ...          DANGOTE CEMENT PLC
# 62236   22.1540  ...          LAFARGE AFRICA PLC
# ...

# %%
#view the shape of the data
#DataFrame.shape tells you the number of rows and columns contained in the dataframe
data.shape
# Out:
# (62240, 27)

# %%
data.describe()
# Out:
#                 S/N     BANK_CODE  BANK_NUMBERING  APP_YEAR      EXC_RATE  \
# count  62238.000000  62238.000000    6.223800e+04   62238.0  62238.000000
# mean   36081.851232     78.550757    2.018999e+10    2019.0    317.541297
# std    25366.821444     74.796830    3.862154e+05       0.0     37.441292
# min        1.000000     11.000000    2.018000e+10    2019.0      0.534000
# 25%    14448.250000     35.000000    2.019000e+10    2019.0    306.950000
# 50%    28869.000000     57.000000    2.019000e+10    2019.0    326.000000
# 75%    57668.750000     68.000000    2.019001e+10    2019.0    326.000000
# max    86390.000000    561.000000    2.019002e+10    2019.0    430.000000
#
#           Bank Code  Bank name
# count  31396.000000        0.0
# mean      78.739967        NaN
# std       73.711340        NaN
# min       11.000000        NaN
# 25%       35.000000        NaN
# 50%       57.000000        NaN
# 75%       70.000000        NaN
# max      501.000000        NaN

# %%
data.columns
# Out:
# Index(['S/N', 'SCANNING_COY', 'PREFIX', 'BANK_CODE', 'BNK_NAM',
#        'BANK_NUMBERING', 'MFNUM', 'APP_YEAR', 'AUTHORIZED_DEALER_DATE',
#        'EXC_RATE', 'CURRENCY', ' FOB_VAL ', 'FREIGHT_VAL', 'CFR', 'USD EQUIV',
#        'PAYMENT_MODE', 'APPLICANT_RCN_CODE', 'APPLICANT_NAME',
#        'IMPORTER_ADDRESS', 'IMPORTER_EMAIL', 'EXPORTER', 'EXPORTER_ADDRESS',
#        'EXPORTER_EMAIL', 'ITEM', 'Bank Code', 'Bank name', 'FOB Value Naira'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62240 entries, 0 to 62239
# Data columns (total 27 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   S/N                     62238 non-null  float64
#  1   SCANNING_COY            62238 non-null  object
#  2   PREFIX                  62238 non-null  object
#  3   BANK_CODE               62238 non-null  float64
#  4   BNK_NAM                 62238 non-null  object
#  5   BANK_NUMBERING          62238 non-null  float64
#  6   MFNUM                   62238 non-null  object
#  7   APP_YEAR                62238 non-null  float64
#  8   AUTHORIZED_DEALER_DATE  62238 non-null  object
#  9   EXC_RATE                62238 non-null  float64
#  10  CURRENCY                62238 non-null  object
#  11   FOB_VAL                62238 non-null  object
#  12  FREIGHT_VAL             62238 non-null  object
#  13  CFR                     62238 non-null  object
# ...

# %%
data.dtypes
# Out:
# S/N                       float64
# SCANNING_COY               object
# PREFIX                     object
# BANK_CODE                 float64
# BNK_NAM                    object
# BANK_NUMBERING            float64
# MFNUM                      object
# APP_YEAR                  float64
# AUTHORIZED_DEALER_DATE     object
# EXC_RATE                  float64
# CURRENCY                   object
#  FOB_VAL                   object
# FREIGHT_VAL                object
# CFR                        object
# USD EQUIV                  object
# PAYMENT_MODE               object
# APPLICANT_RCN_CODE         object
# APPLICANT_NAME             object
# IMPORTER_ADDRESS           object
# IMPORTER_EMAIL             object
# EXPORTER                   object
# EXPORTER_ADDRESS           object
# EXPORTER_EMAIL             object
# ITEM                       object
# Bank Code                 float64
# Bank name                 float64
# FOB Value Naira            object
# dtype: object

# %%
#check for missing data using isna().sum()
data.isna().sum()
# Out:
# S/N                           2
# SCANNING_COY                  2
# PREFIX                        2
# BANK_CODE                     2
# BNK_NAM                       2
# BANK_NUMBERING                2
# MFNUM                         2
# APP_YEAR                      2
# AUTHORIZED_DEALER_DATE        2
# EXC_RATE                      2
# CURRENCY                      2
#  FOB_VAL                      2
# FREIGHT_VAL                   2
# CFR                           2
# USD EQUIV                     1
# PAYMENT_MODE                  2
# APPLICANT_RCN_CODE            2
# APPLICANT_NAME                2
# IMPORTER_ADDRESS              2
# IMPORTER_EMAIL              138
# EXPORTER                      2
# EXPORTER_ADDRESS              2
# EXPORTER_EMAIL                2
# ITEM                          2
# Bank Code                 30844
# Bank name                 62240
# FOB Value Naira               1
# dtype: int64

# %%
#what do the records with empty Bank names mean? Does it mean importer did not input data? 
#TODO: filter the dataframe using BNK_NAM.isna() as filter condition
data[data.BNK_NAM.isna()]
# Out:
#        S/N SCANNING_COY PREFIX  BANK_CODE BNK_NAM  BANK_NUMBERING MFNUM  \
# 62238  NaN          NaN    NaN        NaN     NaN             NaN   NaN
# 62239  NaN          NaN    NaN        NaN     NaN             NaN   NaN
#
#        APP_YEAR AUTHORIZED_DEALER_DATE  EXC_RATE  ... APPLICANT_NAME  \
# 62238       NaN                    NaN       NaN  ...            NaN
# 62239       NaN                    NaN       NaN  ...            NaN
#
#       IMPORTER_ADDRESS IMPORTER_EMAIL EXPORTER EXPORTER_ADDRESS  \
# 62238              NaN            NaN      NaN              NaN
# 62239              NaN            NaN      NaN              NaN
#
#       EXPORTER_EMAIL ITEM Bank Code Bank name         FOB Value Naira
# 62238            NaN  NaN       NaN       NaN   6,936,041,044,072.87
# 62239            NaN  NaN       NaN       NaN                     NaN
#
# [2 rows x 27 columns]

# %%
data[data.ITEM.isna()]
# Out:
#        S/N SCANNING_COY PREFIX  BANK_CODE BNK_NAM  BANK_NUMBERING MFNUM  \
# 62238  NaN          NaN    NaN        NaN     NaN             NaN   NaN
# 62239  NaN          NaN    NaN        NaN     NaN             NaN   NaN
#
#        APP_YEAR AUTHORIZED_DEALER_DATE  EXC_RATE  ... APPLICANT_NAME  \
# 62238       NaN                    NaN       NaN  ...            NaN
# 62239       NaN                    NaN       NaN  ...            NaN
#
#       IMPORTER_ADDRESS IMPORTER_EMAIL EXPORTER EXPORTER_ADDRESS  \
# 62238              NaN            NaN      NaN              NaN
# 62239              NaN            NaN      NaN              NaN
#
#       EXPORTER_EMAIL ITEM Bank Code Bank name         FOB Value Naira
# 62238            NaN  NaN       NaN       NaN   6,936,041,044,072.87
# 62239            NaN  NaN       NaN       NaN                     NaN
#
# [2 rows x 27 columns]

# %%
# why is there no data for rows 62238 and 62239
# Row 62238 contains FOB Value of N6,936,041,044,072.87 but no other information about the transaction? What does this mean?

# %%
#how many unique items were imported Use unique() and check length of the resulting list
len(data[data.ITEM.notna()].ITEM.unique())
# Out:
# 29225

# %%
#Number of items imported 
data[data.ITEM.notna()].ITEM.value_counts()
# Out:
# INDUSTRIAL RAW MATERIAL                                                      785
# RAW MATERIAL FOR INDUSTRIAL USE                                              637
# PHARMACEUTICAL PRODUCTS                                                      397
# BAJAJ RE 4S 198.88CC AUTORICKSHAW IN CKD PACKED CONDITION                    332
# SPARE PARTS                                                                  307
#                                                                             ...
# FER-050 CALMAG 25KG                                                            1
# RAW MATERIALS FOR INDUSTRIAL USE:TOLUENE QTY 14.40MT                           1
# RAW MATERIALS FOR INDUSTRIAL USE:  ISO PROPYL ALCOHOL ( IPA) QTY 12.80 MT      1
# INDUSTRIAL RAW MATERIALS - PRIME ELECTROLYTIC TINPLATE                         1
# CHEMICALS FOR THE PRINTING INDUSTRY                                            1
# Name: ITEM, Length: 29225, dtype: int64

# %%
# frequently used Banks 
data[data.BNK_NAM.notna()].BNK_NAM.value_counts()
# Out:
# Zenith Bank PLC                        12882
# Access Bank PLC                         7147
# Stanbic IBTC Bank PLC                   4977
# Standard Chartered Bank Nigeria LTD     4909
# Citibank Nigeria Limited                4039
# First Bank PLC                          3858
# Guaranty Trust Bank Plc                 3580
# UBA Group                               3506
# Union Bank PLC                          3079
# Fidelity Bank PLC                       2948
# First City Monument Bank PLC            2700
# Ecobank LTD                             2013
# Sterling Bank Plc                       1499
# Polaris Bank Ltd                        1431
# Wema Bank PLC                            968
# Diamond Bank PLC                         591
# Keystone Bank Plc                        487
# Providus Bank                            422
# FSDH Merchant Bank Ltd                   345
# Jaiz Bank Plc                            215
# Unity Bank Group                         195
# ...

# %%
# frequently used payment mode 
data[data.PAYMENT_MODE.notna()].PAYMENT_MODE.value_counts()
# Out:
# Bills for Collection    32591
# Letters of Credit       29647
# Name: PAYMENT_MODE, dtype: int64

# %%
# frequently used currencies 
data[data.CURRENCY.notna()].CURRENCY.value_counts()
# Out:
# USD    52956
# EUR     7578
# GBP      841
# CNY      577
# ZAR      132
# JPY      100
# CHF       46
# SEK        7
# CFA        1
# Name: CURRENCY, dtype: int64

# %%
# frequent IMPORTERS 
data[data.APPLICANT_NAME.notna()].APPLICANT_NAME.value_counts()
# Out:
# NESTLE NIG. PLC                               960
# BRITISH AMERICAN TOBACCO (NIGERIA) LIMITED    804
# DAG INDUSTRIES NIGERIA LIMITED.               608
# NIGERIAN BOTTLING COMPANY LIMITED             568
# EUROCHEMCO VENTURES LIMITED                   551
#                                              ...
# LUIGRAD COMPANY NIG. LTD.                       1
# HABRO INVESTMENTS LIMITED                       1
# JULLYMAX INTERNATIONAL LIMITED                  1
# ASONA INVESTMENTS NIGERIA LIMITED               1
# DE-OBABOB INVESTMENT LTD. CALABAR               1
# Name: APPLICANT_NAME, Length: 3373, dtype: int64

# %%
# frequently used EXPORTER 
data[data.EXPORTER.notna()].EXPORTER.value_counts()
# Out:
# AUTOWORLD INTERNATIONAL FZCO                 828
# ZEN GLOBAL DMCC                              588
# SNETOR CHIMIE                                512
# PZ CUSSONS SINGAPORE PTE LTD                 507
# ASSUDAMAL & SONS (HK) LIMITED                441
#                                             ...
# GODREJ CONSUMER PRODUCTS LIMITED               1
# FOURRTS (INDIA) LABORATORIES PVT. LIMITED      1
# Manuchar  Nv                                   1
# ELECTRO MECHANICAL WAREHOUSE EMW S.A.L         1
# ECO PRESSROOM PRODUCTS (PTY) LTD               1
# Name: EXPORTER, Length: 12278, dtype: int64

# %%
# frequently used EXPORTER 
data.FOB_Value_Naira.mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of 0               37,294,560.00
# 1                1,881,164.26
# 2                1,397,662.29
# 3              180,964,845.81
# 4               20,378,493.25
#                  ...
# 62235           11,449,159.75
# 62236            2,077,863.54
# 62237            7,565,506.20
# 62238    6,936,041,044,072.87
# 62239                     NaN
# Name: FOB_Value_Naira, Length: 62240, dtype: object>

# %%
data.drop(['S/N', 'SCANNING_COY', 'PREFIX', 'BANK_CODE', 'BANK_NUMBERING', 'MFNUM', 'APP_YEAR', 'EXC_RATE', 'FREIGHT_VAL', 'CFR', 'USD EQUIV', 'APPLICANT_RCN_CODE', 'IMPORTER_ADDRESS', 'IMPORTER_EMAIL', 'EXPORTER_ADDRESS', 'EXPORTER_EMAIL', 'Bank Code'], axis=1, inplace=True)

# %%
data.head()
# Out:
#                         BNK_NAM AUTHORIZED_DEALER_DATE CURRENCY    FOB_VAL   \
# 0  First City Monument Bank PLC              31-Jan-19      CFA  69,840,000
# 1               Access Bank PLC              23-Jan-19      CHF       6,034
# 2      Citibank Nigeria Limited              27-Feb-19      CHF       4,526
# 3      Citibank Nigeria Limited               1-Mar-19      CHF     585,990
# 4      Citibank Nigeria Limited              12-Apr-19      CHF      66,118
#
#            PAYMENT_MODE               APPLICANT_NAME  \
# 0  Bills for Collection  SUNSTEEL INDUSTRIES LIMITED
# 1  Bills for Collection              NESTLE NIG. PLC
# 2  Bills for Collection              NESTLE NIG. PLC
# 3  Bills for Collection              NESTLE NIG. PLC
# 4  Bills for Collection              NESTLE NIG. PLC
#
#                                EXPORTER  \
# 0                ENSCO SERVICES LIMITED
# 1                Solventek Trading DMCC
# 2                    JAT OFFSHORE S.A.L
# ...

# %%
#total sales quantities by country
data.groupby('APPLICANT_NAME').ITEM.sum().sort_values(ascending=False)[:10]
# Out:
# APPLICANT_NAME
# ASHOLAKINS AGRO ALLIED LTD                          sim cards500.250 MT SODA ASH LIGHTL-LYSINE
# ALBERT ADESONA NIGERIA LIMITED               setting tool, rolls of paper machinery, steel ...
# HALLMARK GLOBAL PETROLEUM LIMITED                                        scaffolding equipment
# KOZA INVITATIONS NIGERIA LIMITED.                                      pet folio for water cup
# RYT PRINTING & PACKAGING LTD                                            paper boardPAPER BOARD
# WINNERS PEACE IND. LTD                       motorcycle spare partsCERAMIC INSULATORS ART N...
# LOTUS PLASTIC LTD                            lndustrial Equipment for Liftinq and HandlinqI...
# EXCELSIOR AFRO VENTURES LIMITED LAGOS        lain Paper in Sheets - (Raw Materials for prin...
# KABEER OLA INTEGRATED GLOBAL LIMITED         knapsack sprayer for agricultural chemicalsNON...
# SYLVESTER MBANEFO ELECTRONICS NIGERIA LTD                                             inverter
# ...

# %%
top_ten = data.groupby('ITEM').FOB_Value_Naira.sum().sort_values(ascending=False)[:10]
top_ten
# Out:
# ITEM
# CAPSICUM OLEORESIN- RAW MATERIAL FOR INDUSTRIAL USE                                        999,717.30
# 10,000MT 10% MORE 10% LESS US NO.2 OR BETTER HARD AMBER DURUM WHEAT IN BULK            999,691,625.00
# FACTORY MATERIAL                                                               999,380.095,835,726.00
# PVC NORMAL CLEAR SHEET 0.13mm*1200mm*200m (24PHR) RAW MATERIAL                         998,650,996.25
# ORAL B TOOTHPASTE AS PER PFI# NIG AUGUST19Paste DATED 26 Aug. 2019                     997,775,364.84
# DUOZOL TABLETS (OFLOAXACIN & ORNIDAZOLE TABLETS)                                           997,560.00
# 5,000 METRIC TONS OF JET A1 (+/-10%)                                                   997,560,000.00
# 5,000 MT OF ATK (+/-10%)                                                               997,560,000.00
# MECHANICAL BROOM PART                                                                  997,262,500.00
# ...

# %%
#use horizontal bar chart to visualize top 10
#use the series index as vertical axis and series values as horizontal axis of the barh() plot
plt.figure(figsize=(15,10))
plt.barh(y=top_ten.index, width=top_ten)
plt.show()

# %%
# %%time
#view relationships between columns
#i'm doing pairplot on just a subset of the data because it runs for a w
sns.pairplot(data.sample(7))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <timed eval> in <module>
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2094     # Set up the PairGrid
#    2095     grid_kws.setdefault("diag_sharey", diag_kind == "hist")
# -> 2096     grid = PairGrid(data, vars=vars, x_vars=x_vars, y_vars=y_vars, hue=hue,
#    2097                     hue_order=hue_order, palette=palette, corner=corner,
# ...

# %%
#import pandas-profiling
from pandas_profiling import ProfileReport
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1700/3674835762.py in <module>
#       1 #import pandas-profiling
# ----> 2 from pandas_profiling import ProfileReport
#
# ModuleNotFoundError: No module named 'pandas_profiling'
